# %% [markdown]
# # **Importing the required libraries**

# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %% [markdown]
# # **Here, we are analysing the stock of Dr. Reddy's Laboratories Limited**

# %%
# Setting up the Ticker
ticker = 'DRREDDY.BO'

# %% [markdown]
# **Fetching the data using Start and End Date**

# %%
# Downloading the customised stock data
# setting the start and end date
dr = yf.download(ticker, start='2022-04-01', end='2023-03-31')
dr
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2022-04-01  4320.000000  4334.200195  4267.600098  4278.649902  4245.456543
# 2022-04-04  4360.000000  4360.000000  4270.600098  4317.250000  4283.756836
# 2022-04-05  4349.000000  4407.899902  4304.450195  4325.100098  4291.545898
# 2022-04-06  4355.000000  4355.000000  4268.000000  4272.450195  4239.304688
# 2022-04-07  4311.000000  4357.399902  4280.549805  4316.600098  4283.112305
# ...                 ...          ...          ...          ...          ...
# 2023-03-23  4489.950195  4500.000000  4434.299805  4447.950195  4413.443359
# 2023-03-24  4423.399902  4498.000000  4423.399902  4462.299805  4427.681641
# 2023-03-27  4472.049805  4527.049805  4472.000000  4486.100098  4451.296875
# 2023-03-28  4483.000000  4547.450195  4480.500000  4528.299805  4493.169434
# ...

# %%
# Checking the head and tail of the data
dr.head()
# Out:
#               Open         High          Low        Close    Adj Close  Volume
# Date
# 2022-04-01  4320.0  4334.200195  4267.600098  4278.649902  4245.456543    7872
# 2022-04-04  4360.0  4360.000000  4270.600098  4317.250000  4283.756836   13321
# 2022-04-05  4349.0  4407.899902  4304.450195  4325.100098  4291.545898   17270
# 2022-04-06  4355.0  4355.000000  4268.000000  4272.450195  4239.304688   11593
# 2022-04-07  4311.0  4357.399902  4280.549805  4316.600098  4283.112305    6265

# %%
dr.tail()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2023-03-23  4489.950195  4500.000000  4434.299805  4447.950195  4413.443359
# 2023-03-24  4423.399902  4498.000000  4423.399902  4462.299805  4427.681641
# 2023-03-27  4472.049805  4527.049805  4472.000000  4486.100098  4451.296875
# 2023-03-28  4483.000000  4547.450195  4480.500000  4528.299805  4493.169434
# 2023-03-29  4550.000000  4575.000000  4522.950195  4564.500000  4529.088867
#
#             Volume
# Date
# 2023-03-23    4699
# 2023-03-24    4333
# 2023-03-27    4264
# 2023-03-28   33422
# 2023-03-29    8544

# %%
# Checking the info
dr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 247 entries, 2022-04-01 to 2023-03-29
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       247 non-null    float64
#  1   High       247 non-null    float64
#  2   Low        247 non-null    float64
#  3   Close      247 non-null    float64
#  4   Adj Close  247 non-null    float64
#  5   Volume     247 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 13.5 KB

# %%
# Describing the data
dr.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count   247.000000   247.000000   247.000000   247.000000   247.000000
# mean   4321.742309  4364.101026  4277.317199  4319.107090  4285.599636
# std     143.636357   141.004798   145.933662   143.940575   142.823901
# min    3843.699951  3898.000000  3787.550049  3874.850098  3844.789062
# 25%    4250.675049  4295.699951  4205.250000  4248.099854  4215.143311
# 50%    4332.049805  4376.200195  4293.799805  4332.799805  4299.186035
# 75%    4415.549805  4455.725098  4371.449951  4413.574951  4379.334473
# max    4605.000000  4645.549805  4547.850098  4592.350098  4556.722656
#
#               Volume
# count     247.000000
# mean    16230.558704
# std     25603.345424
# min      1291.000000
# 25%      5335.500000
# 50%      8433.000000
# 75%     17740.000000
# max    182290.000000

# %% [markdown]
# # Fetching the data using period
# # period: The valid frequencies are 1d, 5d, 1mo, 3mo, 6mo, 1y, 2y, 5y, 10, ytd.

# %%
df = yf.download(ticker, period='1d')
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(11, 4), dpi=80, facecolor='beige')
plt.grid(True, color='blue', linestyle='--', linewidth=0.5, alpha=0.5)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Adjusted Close Price Over Time')
plt.plot(df.Close)
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
dr = yf.download(ticker, period='5d')
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(11, 4), dpi=80, facecolor='cyan')
plt.grid(True, color='blue', linestyle='--', linewidth=0.5, alpha=0.5)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Adjusted Close Price Over Time')
plt.plot(dr.Close)
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
dr = yf.download(ticker, period='1mo')
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(11, 4), dpi=80, facecolor='teal')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.5)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Adjusted Close Price Over Time')
plt.plot(dr.Close)
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
dr = yf.download(ticker, period='3mo')
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(11, 4), dpi=80, facecolor='beige')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.5)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Adjusted Close Price Over Time')
plt.plot(dr.Close)
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
dr = yf.download(ticker, period='6mo')
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(11, 4), dpi=80, facecolor='lightgray')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.5)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Adjusted Close Price Over Time')
plt.plot(dr.Close)
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
dr = yf.download(ticker, period='1y')
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(11, 4), dpi=80, facecolor='teal')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.5)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Adjusted Close Price Over Time')
plt.plot(dr.Close)
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
dr = yf.download(ticker, period='2y')
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(11, 4), dpi=80, facecolor='beige')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.5)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Adjusted Close Price Over Time')
plt.plot(dr.Close)
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
dr = yf.download(ticker, period='5y')
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(11, 4), dpi=80, facecolor='darkgray')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.5)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Adjusted Close Price Over Time')
plt.plot(dr.Close)
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
dr = yf.download(ticker, period='10y')
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(11, 4), dpi=80, facecolor='cyan')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.5)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Adjusted Close Price Over Time')
plt.plot(dr.Close)
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
dr = yf.download(ticker, period='ytd')
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(11, 4), dpi=80, facecolor='lightgray')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.5)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Adjusted Close Price Over Time')
plt.plot(dr.Close)
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# # Fetching the data using period and Interval
# # Interval: The valid intervals are 1m, 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo.

# %%
dr = yf.download(ticker, period='1d', interval='1m')
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(11, 4), dpi=80, facecolor='beige')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.5)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Adjusted Close Price Over Time')
plt.plot(dr.Close)
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
dr = yf.download(ticker, period='1mo', interval='5m')
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(11, 4), dpi=80, facecolor='teal')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.5)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Adjusted Close Price Over Time')
plt.plot(dr.Close)
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
dr = yf.download(ticker, period='1mo', interval='15m')
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(11, 4), dpi=80, facecolor='beige')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.5)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Adjusted Close Price Over Time')
plt.plot(dr.Close)
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
dr = yf.download(ticker, period='1mo', interval='30m')
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(11, 4), dpi=80, facecolor='teal')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.5)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Adjusted Close Price Over Time')
plt.plot(dr.Close)
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
dr = yf.download(ticker, period='1mo', interval='60m')
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(11, 4), dpi=80, facecolor='darkgray')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.5)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Adjusted Close Price Over Time')
plt.plot(dr.Close)
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
dr = yf.download(ticker, period='1mo', interval='90m')
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(11, 4), dpi=80, facecolor='cyan')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.5)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Adjusted Close Price Over Time')
plt.plot(dr.Close)
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
dr = yf.download(ticker, period='3mo', interval='1wk')
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(11, 4), dpi=80, facecolor='darkgray')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.5)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Adjusted Close Price Over Time')
plt.plot(dr.Close)
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
dr = yf.download(ticker, period='ytd', interval='1h')
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(11, 4), dpi=80, facecolor='beige')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.5)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Adjusted Close Price Over Time')
plt.plot(dr.Close)
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
dr = yf.download(ticker, period='max', interval='1d')
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(11, 4), dpi=80, facecolor='lightgray')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.5)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Adjusted Close Price Over Time')
plt.plot(dr.Close)
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
dr = yf.download(ticker, period='max', interval='5d')
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(11, 4), dpi=80, facecolor='teal')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.5)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Adjusted Close Price Over Time')
plt.plot(dr.Close)
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
dr = yf.download(ticker, period='max', interval='1wk')
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(11, 4), dpi=80, facecolor='darkgray')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.5)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Adjusted Close Price Over Time')
plt.plot(dr.Close)
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
dr = yf.download(ticker, period='max', interval='1mo')
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(11, 4), dpi=80, facecolor='cyan')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.5)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Adjusted Close Price Over Time')
plt.plot(dr.Close)
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
dr = yf.download(ticker, period='max', interval='3mo')
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(11, 4), dpi=80, facecolor='beige')
plt.grid(True, color='gray', linestyle='--', linewidth=0.5, alpha=0.5)
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Adjusted Close Price Over Time')
plt.plot(dr.Close)
plt.show()
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %% [markdown]
# # **Resample Stock Data**

# %%
dr = yf.download('DRREDDY.BO', period='1wk', interval='1m')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
dr
# Out:
#                                   Open         High          Low        Close  \
# Datetime
# 2024-01-10 09:15:00+05:30  5768.700195  5771.000000  5753.649902  5758.450195
# 2024-01-10 09:16:00+05:30  5775.000000  5775.000000  5757.399902  5757.399902
# 2024-01-10 09:17:00+05:30  5760.000000  5762.149902  5760.000000  5762.149902
# 2024-01-10 09:18:00+05:30  5775.250000  5775.250000  5775.250000  5775.250000
# 2024-01-10 09:19:00+05:30  5775.049805  5786.000000  5775.049805  5776.149902
# ...                                ...          ...          ...          ...
# 2024-01-16 15:25:00+05:30  5759.750000  5762.200195  5759.750000  5762.200195
# 2024-01-16 15:26:00+05:30  5763.750000  5763.750000  5763.750000  5763.750000
# 2024-01-16 15:27:00+05:30  5760.000000  5760.000000  5760.000000  5760.000000
# 2024-01-16 15:28:00+05:30  5760.000000  5760.000000  5760.000000  5760.000000
# 2024-01-16 15:29:00+05:30  5756.000000  5760.000000  5755.600098  5758.100098
#
# ...

# %%
y=dr.resample('10T').mean()
y
# Out:
#                                   Open         High          Low        Close  \
# Datetime
# 2024-01-10 09:10:00+05:30  5770.800000  5773.879980  5764.269922  5765.879980
# 2024-01-10 09:20:00+05:30  5762.061089  5762.505534  5757.783312  5758.599935
# 2024-01-10 09:30:00+05:30  5728.711155  5730.661187  5727.477865  5729.461209
# 2024-01-10 09:40:00+05:30  5739.099902  5739.119922  5737.269922  5737.269922
# 2024-01-10 09:50:00+05:30  5722.950012  5723.375000  5720.287476  5720.449951
# ...                                ...          ...          ...          ...
# 2024-01-16 14:40:00+05:30  5755.962524  5756.487427  5755.400024  5755.924927
# 2024-01-16 14:50:00+05:30  5751.519922  5751.519922  5751.519922  5751.519922
# 2024-01-16 15:00:00+05:30  5757.483398  5757.483398  5756.833333  5756.833333
# 2024-01-16 15:10:00+05:30  5757.012512  5757.206238  5756.887573  5757.081299
# 2024-01-16 15:20:00+05:30  5758.879980  5760.064990  5758.614990  5759.739990
#
# ...

# %%
# Plotting the 10minute stock data
y.Close.plot(figsize=(11,4))
# Out:
# <Axes: xlabel='Datetime'>

# %%
r=y.resample('15T').sum()
r
# Out:
#                                    Open          High           Low  \
# Datetime
# 2024-01-10 09:00:00+05:30   5770.800000   5773.879980   5764.269922
# 2024-01-10 09:15:00+05:30   5762.061089   5762.505534   5757.783312
# 2024-01-10 09:30:00+05:30  11467.811057  11469.781109  11464.747786
# 2024-01-10 09:45:00+05:30   5722.950012   5723.375000   5720.287476
# 2024-01-10 10:00:00+05:30  11428.860010  11431.130029  11424.359961
# ...                                 ...           ...           ...
# 2024-01-16 14:15:00+05:30   5748.129980   5748.650000   5746.779980
# 2024-01-16 14:30:00+05:30  11504.879191  11505.404093  11503.216593
# 2024-01-16 14:45:00+05:30   5751.519922   5751.519922   5751.519922
# 2024-01-16 15:00:00+05:30  11514.495911  11514.689636  11513.720907
# 2024-01-16 15:15:00+05:30   5758.879980   5760.064990   5758.614990
#
#                                   Close     Adj Close      Volume
# Datetime
# ...

# %%
# Plotting the 15minutes data
r.Close.plot(figsize=(11, 4))
# Out:
# <Axes: xlabel='Datetime'>

# %%
# Plotting the original 'Close' stock data
dr.Close.plot(figsize=(11,4))
# Out:
# <Axes: xlabel='Datetime'>

# %% [markdown]
# # Revenues: fetching the revenues for Dr.Reddy Laboratories

# %%
ticker='DRREDDY.BO'
drr=yf.Ticker(ticker)

# %%
dir(drr)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_analysis',
#  '_base_url',
#  '_data',
#  '_download_options',
#  '_earnings',
#  '_earnings_dates',
#  '_expirations',
#  '_fast_info',
#  '_fetch_ticker_tz',
#  '_financials',
#  '_fix_bad_stock_split',
#  '_fix_missing_div_adjust',
#  '_fix_prices_sudden_change',
#  '_fix_unit_mixups',
#  '_fix_unit_random_mixups',
#  '_fix_unit_switch',
#  '_fix_zeroes',
#  '_fundamentals',
#  '_get_ticker_tz',
#  '_history',
#  '_history_metadata',
#  '_history_metadata_formatted',
#  '_holders',
#  '_isin',
#  '_news',
#  '_options2df',
#  '_quote',
# ...

# %%
revenue = drr.financials.loc['Total Revenue']
revenue
# Out:
# 2023-03-31    245879000000.0
# 2022-03-31    214391000000.0
# 2021-03-31    189722000000.0
# 2020-03-31    174600000000.0
# Name: Total Revenue, dtype: object

# %%
revenue.plot(figsize=(10,4))
plt.title('Revenues of Dr.Reddy Laboratories')
plt.show()

# %% [markdown]
# # EBIT

# %%
EBIT = drr.financials.loc['EBIT']
EBIT
# Out:
# 2023-03-31    61795000000.0
# 2022-03-31    33256000000.0
# 2021-03-31    27383000000.0
# 2020-03-31    19015000000.0
# Name: EBIT, dtype: object

# %%
EBIT.plot(figsize=(10,4))
plt.title('Earnings Before Interest and Taxes')
plt.show()

# %% [markdown]
# # Balance sheet, cash flows and other information

# %%
#show income statement
drr.financials
# Out:
#                                                         2023-03-31  \
# Tax Effect Of Unusual Items                            297750000.0
# Tax Rate For Calcs                                            0.25
# Normalized EBITDA                                    73240000000.0
# Total Unusual Items                                   1191000000.0
# Total Unusual Items Excluding Goodwill                1191000000.0
# Net Income From Continuing Operation Net Minori...   45067000000.0
# Reconciled Depreciation                              12636000000.0
# Reconciled Cost Of Revenue                          106536000000.0
# EBITDA                                               74431000000.0
# EBIT                                                 61795000000.0
# Net Interest Income                                   -248000000.0
# Interest Expense                                      1428000000.0
# Interest Income                                       1180000000.0
# ...

# %%
#show balance sheet
drr.balance_sheet
# Out:
#                                                      2023-03-31  \
# Treasury Shares Number                                 371144.0
# Ordinary Shares Number                              166156732.0
# Share Issued                                        166527876.0
# Net Debt                                           5411000000.0
# Total Debt                                        13472000000.0
# ...                                                         ...
# Cash Cash Equivalents And Short Term Investments  61797000000.0
# Other Short Term Investments                      56018000000.0
# Cash And Cash Equivalents                          5779000000.0
# Cash Equivalents                                   2743000000.0
# Cash Financial                                     3036000000.0
#
#                                                      2022-03-31  \
# Treasury Shares Number                                 468471.0
# Ordinary Shares Number                              165957378.0
# ...

# %%
#show other info
drr.info
# Out:
# {'address1': '8-2-337, Road No. 3',
#  'address2': 'Banjara Hills',
#  'city': 'Hyderabad',
#  'zip': '500034',
#  'country': 'India',
#  'phone': '91 40 4900 2900',
#  'website': 'https://www.drreddys.com',
#  'industry': 'Drug Manufacturers - Specialty & Generic',
#  'industryKey': 'drug-manufacturers-specialty-generic',
#  'industryDisp': 'Drug Manufacturers - Specialty & Generic',
#  'sector': 'Healthcare',
#  'sectorKey': 'healthcare',
#  'sectorDisp': 'Healthcare',
# ...
